# %% [markdown]
# <a href="https://colab.research.google.com/github/Nidzoki/PMFSTMachineLearning/blob/main/vjezba1/1_Formatiranje_tekstualnih_celija.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![thumbnail](https://drive.google.com/uc?id=1P_Mbcld2ZKcp5rUZuaa6Hrz8_d5G37Hf)
#
# # **Formatiranje tekstualnih ćelija:** Osnove Markdowna
#
# Za formatiranje tekstualnih ćelija koristi se jednostavan markup jezik - **Markdown**.
#
# Dvoklikom na odabranu ćeliju možete vidjeti njen izvorni kod.

# %% [markdown]
# ### **1. Naslovi**
#
# ```
# Naslove dodajemo na sljedeći način:
# # Naslov 1
# # Naslov 2
# ## Naslov 2.1.
# ### Naslov 2.1.1.
# ```

# %% [markdown]
# #### 1.1. Podnaslov

# %% [markdown]
# ##### 1.1.1. Podnaslov podnaslova

# %% [markdown]
# ### **2. Formatiranje teksta**
#
# - **bold:** `**`
# -  *italic*: `*`
# - ***bold-italic***: `***`
# - ~~precrtan~~: `~~`

# %% [markdown]
# ##### **Zadatak:**
#
# Formatirajte sljedeći tekst tako da upotrijebite sva četiri stila navedena poviše.
#
# **Artificial intelligence** (AI), sometimes called **machine intelligence**, is intelligence demonstrated by machines, unlike the natural intelligence displayed by humans and animals. Leading AI textbooks define the field as the study of "*intelligent agents*": any device that perceives its environment and takes actions that maximize its chance of successfully achieving its goals. Colloquially, the term ***"artificial intelligence"*** is often used to describe machines ~(or computers)~ that mimic "cognitive" functions that humans associate with the human mind, such as "learning" and "problem solving".

# %% [markdown]
# ### **3. Prelazak u novi red: `<br>`**

# %% [markdown]
# ##### **Zadatak:**
#
# Rečenica 1. <br><br><br>Ovu rečenicu "prebacite" tri retka ispod Rečenice 1.

# %% [markdown]
# ### ***4. Dodavanje horizontalne linije:  `---`***

# %% [markdown]
# ##### **Zadatak:**
# Ulomke o različitim primjenama umjetne inteligencije odvojite horizontalnim linijama.
#
# <br>
#
# **PRIMJENE UMJETNE INTELIGENCIJE**
#
#
# ***Autonomni automobili***: U autonomnim je automobilima potrebno primjenjivati kombinaciju raznih tehnika umjetne inteligencije: pretraživanje i planiranje upotrebljavaju se za pronalaženje najprikladnije rute od točke A do točke B, računalni vid potreban je za utvrđivanje prepreka, a sposobnost donošenja odluka u neizvjesnim okolnostima služi za snalaženje u složenom i dinamičnom okruženju. Budući da je prijevoz toliko važan dio našeg svakodnevnog života, vjerojatno ima i drugih posljedica o kojima još nismo razmišljali.
#
# ---
#
# ***Preporuka sadržaja*** : Svakodnevno nailazimo na razne informacije, a mnoge su od njih personalizirane. To su, na primjer, sadržaji na Facebooku, Twitteru, Instagramu i u drugim društvenim medijima, internetski oglasi, preporuke glazbe na Spotifyu te preporuke filmova na Netflixu, HBO-u i u okviru drugih usluga internetskog prijenosa sadržaja. Sadržaj koji nude personaliziraju i mnogi internetski izdavači, kao što su stranice s elektroničkom inačicom novina i stranice radiotelevizijskih kuća, te internetski pretraživači kao što je Google.
#
# ---
#
# ***Obrada slika i videozapisa***: Sustav za prepoznavanje lica već ima brojne korisničke, poslovne i administrativne primjene, na primjer za grupiranje fotografija prema osobama koje su na njima prikazane, automatsko označavanje na društvenim mrežama i provjeru putovnica. Slične tehnike mogu se, na primjer, upotrebljavati za prepoznavanje drugih vozila i prepreka oko autonomnog automobila ili, primjerice, za procjenu populacija divljih biljnih i životinjskih vrsta.

# %% [markdown]
# ### **5. Uvučeni tekst: `>`, `>>`**

# %% [markdown]
# ##### **Zadatak:**
#
# Formatirajte tekst ispod tako da dobijete
#
# ![uvuceni tekst rjesenje](https://drive.google.com/uc?id=10oAiTCsvYqo3NVa2ozEWLQtSxWdEcHAc)
#
# ---
#
#
# Neki tekst.
#
# >Uvučeni tekst prva razina.
#
# >>Uvučeni tekst druga razina.
#
# >>>Uvučeni tekst treća razina.

# %% [markdown]
# ### **6. Numerirane i nenumerirane liste s podlistama**
#
# Numerirana lista
# ```
# 1. item 1
# 2. item 2
#   1. item 2.1
#   2. item 2.2
# 3. item 3
# ```
#
# Nenumerirana lista
# ```
# - item 1
# - item 2
#   - item 2.1
#   - item 2.2
# - item 3
# ```

# %% [markdown]
# ##### **Zadatak:**
#
# U tekstualnoj ćeliji ispod napravite sljedeću listu:
#
#
# <img src = "https://drive.google.com/uc?id=1_Q65pKgt7dMQuGeddmW5LhNbqhPYJ1xT" alt="Slika_lista" width="200">

# %% [markdown]
# **Rješenje:**
# ```
# - item1
#   - item 1.1
#   - item 1.2
# - item 2
# - item 3
#   - item 3.1
#     - item 3.1.1
#     - item 3.1.2
#   - item 3.2
# - item 4
# ```

# %% [markdown]
# ### **7. Pisanje matematičkih izraza koristeći $\LaTeX$**

# %% [markdown]
# Matematičke izraze možemo pisati u istom retku s tekstom koristeći znak  `$`, primjerice $e^{i\pi} + 1 = 0$.
#
# Ili zasebno koristeći `$$`:
#
# $$e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i.$$

# %% [markdown]
# ##### **Zadatak:**
#
# Napišite formulu za `razliku kvadrata` u istom retku s ovim tekstom. Formula za razliku kvadrata - $a^2 - b^2 = (a - b)(a + b)$
# Formulu za `kvadrat razlike` napišite zasebeno u novom retku.
#
# $$ a^2 - b^2 = (a - b)(a + b) $$

# %% [markdown]
# ### **8. Tablice**
#
# ```
# STUPAC 1 | STUPAC 2
#  --- | ---
# ćelija 1,1 | ćelija 1,2
# ćelija 2,1 | ćelija 2,2
# ```

# %% [markdown]
# ##### **Zadatak:**
#
# U tekstualnoj ćeliji ispod napravite tablicu istinitosti za jedan od logičkih sklopova.
#
# <br>
#
# <img src="https://www.gsnetwork.com/wp-content/uploads/2023/01/digital-logic-gates-symbols-and-truth-tables.jpg" width="650" height="400" alt="Slika_sklopovi">

# %% [markdown]
# ### XNOR
# <table>
#   <tr>
#     <th>A</th>
#     <th>B</th>
#     <th>OUTPUT</th>
#   </tr>
#   <tr>
#     <td>0</td>
#     <td>0</td>
#     <td>1</td>
#   </tr>
#   <tr>
#     <td>0</td>
#     <td>1</td>
#     <td>0</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>0</td>
#     <td>0</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>1</td>
#     <td>1</td>
#   </tr>
# </table>

# %% [markdown]
# ### **9. Linkovi**
#
# - https://colab.research.google.com/notebooks/intro.ipynb
# - [Uvod u Colaboratory](https://colab.research.google.com/notebooks/intro.ipynb)

# %% [markdown]
# ##### **Zadatak:**
#
# Koji je odnos sljedećih pojmova:
# - ***umjetna inteligencija***
# - ***strojno učenje***
# - ***duboko učenje***?
#
# Odgovor pronađite na internetu te dajte link na stranicu na kojoj ste pronašli odgovor na zadano pitanje.

# %% [markdown]
# **Odgovor:** https://pcchip.hr/ostalo/tech/razlike-izmedu-strojnog-ucenja-ai-i-dubokog-ucenja/

# %% [markdown]
# ### **10. Slike**

# %% [markdown]
# #### ***10.1. Dodavanje slike s weba:***
#
#
# > `![alternativni tekst](URL slike)`
#
# > HTML sintaksa: `<img src="URL" alt="alternativni tekst">`

# %% [markdown]
# ##### **Zadatak:**
#
# Na webu pronađite sliku koja prikazuje odnos *umjetne inteligencije*, *strojnog učenja* i *dubokog učenja* i prikažite je ovdje.
#
# <img src= "https://lh6.googleusercontent.com/NOiHFKYEPALZNBvv4KOH99nOwVpDetsFs2J4utve9lR0KYpzSL3PW3XemWcq87PtLLxV9JAOht2aWEH5_AEMTbLghhd5OhKhUTQX07KhLdqwYX9gs7sAl1CNWBdPLatqdX2PB0xw" alt="slika koja prikazuje odnos umjetne inteligencije, strojnog učenja i dubokog učenja">

# %% [markdown]
# #### ***10.2. Dodavanje slike lokalno pohranjene na računalu:***
#
# 1. Uploadati sliku na Google Drive
#
# 2. Podijeliti link na sliku
#   - desni klik na sliku
#   - **get link**
#   - postaviti da svatko s linkom može vidjeti datoteku
#       - ~~restricted~~
#       - **anyone with the link** <br>
#       ![slika_anyone_with_link](https://drive.google.com/uc?id=1k59GmrGqUm_vK9zpc8Vt3sydz8Nqwjz_)
#
# 3. Format kopiranog linka (`https://drive.google.com/file/d/<ID slike>/view?usp=sharing`) <br>
#   **promijeniti u  format** `https://drive.google.com/uc?id=<ID slike>`!
#
# 3. Unutar tekstualne ćelije dodati liniju: `![dodana_slika](https://drive.google.com/uc?id=<ID slike>)`
# > Primjerice:    `![dodana_slika](https://drive.google.com/uc?id=1h9qgqjn9j2gAjEO8Miy-6uT3HGJVQpA1)`
#
# 4. Dodana slika: <br><br>
# ![dodana_slika](https://drive.google.com/uc?id=1h9qgqjn9j2gAjEO8Miy-6uT3HGJVQpA1)

# %% [markdown]
# ##### **Zadatak:**
#
# Unutar bilježnice dodajte sliku lokalno prohranjenu na vašem računalu. *Pazite da je i drugi mogu vidjeti kada im pošaljete svoju bilježnicu.*
#
#
# Dodana slika:
# <br>
# <br>
# ![dodana_slika](https://drive.google.com/file/d/1-TEmRngQbF-W4BU79OblX8dZcqfDBhT3/view?usp=sharing)
